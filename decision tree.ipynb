# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter("ignore")

# %%
d=pd.read_csv(r'C:\\Users\\Molika\\Downloads\\iris.csv')

# %%
d
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   5.1          149 non-null    float64
#  1   3.5          149 non-null    float64
#  2   1.4          149 non-null    float64
#  3   0.2          149 non-null    float64
#  4   Iris-setosa  149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
d.isnull().sum()
# Out:
# 5.1            0
# 3.5            0
# 1.4            0
# 0.2            0
# Iris-setosa    0
# dtype: int64

# %%
d.columns =['SepalLength', 'SepalWidth','PetalLength','PetalWidth','Species']

# %%
d.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   149.000000  149.000000   149.000000  149.000000
# mean      5.848322    3.051007     3.774497    1.205369
# std       0.828594    0.433499     1.759651    0.761292
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.400000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
d['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# Name: Species, dtype: int64

# %%
d
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            4.9         3.0          1.4         0.2     Iris-setosa
# 1            4.7         3.2          1.3         0.2     Iris-setosa
# 2            4.6         3.1          1.5         0.2     Iris-setosa
# 3            5.0         3.6          1.4         0.2     Iris-setosa
# 4            5.4         3.9          1.7         0.4     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 144          6.7         3.0          5.2         2.3  Iris-virginica
# 145          6.3         2.5          5.0         1.9  Iris-virginica
# 146          6.5         3.0          5.2         2.0  Iris-virginica
# 147          6.2         3.4          5.4         2.3  Iris-virginica
# 148          5.9         3.0          5.1         1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
w=d.iloc[:,:4]
v=d.iloc[:,4]

# %%
w
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth
# 0            4.9         3.0          1.4         0.2
# 1            4.7         3.2          1.3         0.2
# 2            4.6         3.1          1.5         0.2
# 3            5.0         3.6          1.4         0.2
# 4            5.4         3.9          1.7         0.4
# ..           ...         ...          ...         ...
# 144          6.7         3.0          5.2         2.3
# 145          6.3         2.5          5.0         1.9
# 146          6.5         3.0          5.2         2.0
# 147          6.2         3.4          5.4         2.3
# 148          5.9         3.0          5.1         1.8
#
# [149 rows x 4 columns]

# %%
v
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 144    Iris-virginica
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# Name: Species, Length: 149, dtype: object

# %%
from sklearn.model_selection import train_test_split
w_train,w_test,v_train,v_test=train_test_split(w,v,random_state=0)

# %%
w_train.shape
# Out:
# (111, 4)

# %%
w_test.shape
# Out:
# (38, 4)

# %%
v_train.shape
# Out:
# (111,)

# %%
v_test.shape
# Out:
# (38,)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(w_train,v_train)
# Out:
# LogisticRegression()

# %%
v_pred=model.predict(w_test)

# %%
v_pred
# Out:
# array(['Iris-virginica', 'Iris-virginica', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-virginica',
#        'Iris-virginica', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-virginica',
#        'Iris-versicolor', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-versicolor', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-setosa', 'Iris-setosa',
#        'Iris-virginica', 'Iris-setosa', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-setosa',
#        'Iris-versicolor', 'Iris-virginica', 'Iris-versicolor'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
confusion_matrix(v_test,v_pred)
# Out:
# array([[14,  0,  0],
#        [ 0, 13,  1],
#        [ 0,  3,  7]], dtype=int64)

# %%
accuracy=accuracy_score(v_test,v_pred)*100
print("Accuracy of the model is {:.2f}".format(accuracy))
# Out:
# Accuracy of the model is 89.47

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf.fit(w_train,v_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(w_test)
print("Train data accuracy:",accuracy_score(y_true = v_train, y_pred=clf.predict(w_train)))
print("Test data accuracy:",accuracy_score(y_true = v_test, y_pred=y_pred))
# Out:
# Train data accuracy: 1.0
# Test data accuracy: 0.868421052631579

# %%
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set(font_scale=1.5)
sns.pairplot(d,hue="Species",size=2,markers='*');
plt.show()

# %%
sns.violinplot(y='Species', x='SepalLength', data=d, inner='quartile')
plt.show()
sns.violinplot(y='Species', x='SepalWidth', data=d, inner='quartile')
plt.show()
sns.violinplot(y='Species', x='PetalLength', data=d, inner='quartile')
plt.show()
sns.violinplot(y='Species', x='PetalWidth', data=d, inner='quartile')
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.heatmap(d.corr(), annot=True, cmap='Set1')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Split our data into the training sets and the testing sets
# Each set has a pair of X and y
w_train, w_test, v_train, v_test = train_test_split(w, v, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()

# Train our model with our training data.
dt.fit(w_train, v_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn import tree

# %%
clf = DecisionTreeClassifier(max_depth = 2, 
                             random_state = 0)# Step 3: Train the model on the data
clf.fit(w_train, v_train)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=0)

# %%
tree.plot_tree(clf);

# %%
fn=['SepalLength','SepalWidth','PetalLength','PetalWidth']
cn=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf,
               feature_names = fn, 
               class_names=cn,
               filled = True);fig.savefig('imagename.png')
